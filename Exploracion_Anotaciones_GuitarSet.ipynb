# %% [markdown]
# # Exploracion Anotaciones disponibles para GuitarSet

# %%
# Disponible en https://github.com/marl/guitarset - creditos al autor

# %%
#Librerias necesarias
import jams
import os
import matplotlib.pyplot as plt

import interpreter as itp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16296/357956256.py in <module>
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 import interpreter as itp
#
# ModuleNotFoundError: No module named 'interpreter'

# %%
# Cambiar esta celda segun la ubicacion de tus archivos *.jams
gs_path = "C:/archivos/"
anno_dir = "annotation/"
excerpt = "04_SS1-68-E_comp_mic.wav"

# %%
# Creacion de variable jam a partir del directorio y archivo a leer
jam = jams.load(os.path.join(gs_path+anno_dir, excerpt))

# %%
instructed_chords = jam.search(namespace='chord')[0]
performed_chords = jam.search(namespace='chord')[1]

# %%
fig = plt.figure(figsize=(8,7), dpi=300)
ax1 = plt.subplot(211)
itp.visualize_jams_pt(jam) #pt for pitch track
ax2 = plt.subplot(212, sharex=ax1)
itp.tablaturize_jams(jam)
plt.xlim(4.9, 10) # this is the time window in seconds that I'm plotting

itp.add_annotations(ax1, performed_chords, ygrow_ratio=0.04, label_xoffset=0.06, label_yoffset=2)
itp.add_annotations(ax2, instructed_chords, ygrow_ratio=0.2, label_xoffset=0.06, label_yoffset=-0.4)
plt.show()
